# %%
import pandas as pd
import matplotlib.pyplot as plt
from gensim.models import KeyedVectors
from data_augmentation import build_extended_dataframe

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /Users/tomek/anaconda3/envs/eng/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
TRAIN_CSV = '/Volumes/DataDrive/merged/en-train.csv'
TEST_CSV = '/Volumes/DataDrive/merged/en-test.csv'

train_df = pd.read_csv(TRAIN_CSV)
test_df = pd.read_csv(TEST_CSV)

# %%
MODEL_PATH = '/Volumes/DataDrive/models/GoogleNews-vectors-negative300.bin'
w2v_model = KeyedVectors.load_word2vec_format(MODEL_PATH, binary=True)

# %% [markdown]
# # Extend train/test dataset
#
# Modify sentences to create new "PerfectMatch" labeled pairs. After generating new dataframe, shuffle it.

# %%
new_train_df = build_extended_dataframe(
    train_df, w2v_model,
    save_to='/Volumes/DataDrive/merged/en-train-extended.csv',
    shuffle=True,
    verbose=True)

# %%
new_test_df = build_extended_dataframe(
    test_df, w2v_model,
    save_to='/Volumes/DataDrive/merged/en-test-extended.csv',
    shuffle=True,
    verbose=True)

# %%
cp = train_df[train_df.relevance == 'PerfectMatch'].copy()
small_df = cp[:10]

# %%
build_extended_dataframe(
    small_df, w2v_model,
    save_to='/Volumes/DataDrive/merged/test-ext.csv',
    shuffle=True,
    verbose=True)
# Out:
# New PerfectMatch size = 30
# New PerfectMatch size = 46
# New PerfectMatch size = 64
# New PerfectMatch size = 81
# New PerfectMatch size = 93
# New PerfectMatch size = 109
# New PerfectMatch size = 127
# New PerfectMatch size = 145
# New PerfectMatch size = 166
# New PerfectMatch size = 168
#     original_question_id         related_question_id  \
# 3           291006556804  291006556804_R152232095899
# 70                   n/a  291006556804_R152232095899
# 153                  n/a  136352899943_R328095001163
# 50                   n/a  242558396314_R565055127097
# 13                   n/a  269007923122_R169377624284
# 134                  n/a  283789971198_R292297771841
# 115                  n/a  307626893524_R258556659327
# 19                   n/a  269007923122_R169377624284
# 37                   n/a  292458976918_R235714755516
# 29                   n/a  269007923122_R169377624284
# 11                   n/a  269007923122_R169377624284
# 30                   n/a  292458976918_R235714755516
# 25                   n/a  269007923122_R169377624284
# 64                   n/a  291006556804_R152232095899
# 63                   n/a  242558396314_R565055127097
# 111                  n/a  307626893524_R258556659327
# 71                   n/a  291006556804_R152232095899
# 162                  n/a  136352899943_R328095001163
# 43                   n/a  292458976918_R235714755516
# 136                  n/a  283789971198_R292297771841
# 157                  n/a  136352899943_R328095001163
# 58                   n/a  242558396314_R565055127097
# 91                   n/a  297314029171_R166108441297
# 159                  n/a  136352899943_R328095001163
# 80                   n/a  291006556804_R152232095899
# 21                   n/a  269007923122_R169377624284
# 130                  n/a  283789971198_R292297771841
# 143                  n/a  283789971198_R292297771841
# 164                  n/a  136352899943_R328095001163
# 99                   n/a  193907720813_R159212984609
# ..                   ...                         ...
# 109                  n/a  307626893524_R258556659327
# 104                  n/a  193907720813_R159212984609
# 32                   n/a  292458976918_R235714755516
# 60                   n/a  242558396314_R565055127097
# 41                   n/a  292458976918_R235714755516
# 18                   n/a  269007923122_R169377624284
# 74                   n/a  291006556804_R152232095899
# 147                  n/a  136352899943_R328095001163
# 149                  n/a  136352899943_R328095001163
# 16                   n/a  269007923122_R169377624284
# 152                  n/a  136352899943_R328095001163
# 10                   n/a  269007923122_R169377624284
# 42                   n/a  292458976918_R235714755516
# 66                   n/a  291006556804_R152232095899
# 141                  n/a  283789971198_R292297771841
# 160                  n/a  136352899943_R328095001163
# 114                  n/a  307626893524_R258556659327
# 0           269007923122  269007923122_R169377624284
# 106                  n/a  193907720813_R159212984609
# 90                   n/a  297314029171_R166108441297
# 7           283789971198  283789971198_R292297771841
# 40                   n/a  292458976918_R235714755516
# 38                   n/a  292458976918_R235714755516
# 17                   n/a  269007923122_R169377624284
# 52                   n/a  242558396314_R565055127097
# 148                  n/a  136352899943_R328095001163
# 146                  n/a  136352899943_R328095001163
# 116                  n/a  307626893524_R258556659327
# 79                   n/a  291006556804_R152232095899
# 86                   n/a  297314029171_R166108441297
#
#                                 original_question_text  \
# 3    When denoting possession with Bureau of Statis...
# 70   when denoting possession with bureau of statis...
# 153  there is a story that a worker at the airport ...
# 50   i am new here and i do not really know how to ...
# 13   i believe that to infinitive as a subject can ...
# 134  i am not confident about my judgement as to wh...
# 115  example : i had no idea how deep the forest re...
# 19   i believe that to infinitive as a subject can ...
# 37   reading great expectations i noticed that numb...
# 29   i believe that to infinitive as a subject can ...
# 11   i believe that to infinitives as a subject can...
# 30   reading terrific expectations i noticed that n...
# 25   i believe that to infinitive as a subject can ...
# 64   when denote possession with bureau of statisti...
# 63   i am new here and i do not really know how to ...
# 111  example : i had no idea how deep the forest ob...
# 71   when denoting possession with bureau of statis...
# 162  there is a story that a worker at the airport ...
# 43   reading great expectations i noticed that numb...
# 136  i am not confident about my judgement as to wh...
# 157  there is a story that a worker at the airport ...
# 58   i am new here and i do not really know how to ...
# 91   examples : jackson was a fan of the show and c...
# 159  there is a story that a worker at the airport ...
# 80   when denoting possession with bureau of statis...
# 21   i believe that to infinitive as a subject can ...
# 130  i am not confident about my judgement as to wh...
# 143  i am not confident about my judgement as to wh...
# 164  there is a story that a worker at the airport ...
# 99   an example just a minute ago i was looking for...
# ..                                                 ...
# 109  instance : i had no idea how deep the forest r...
# 104  an example just a minute ago i was looking for...
# 32   reading great expectations i noticing that num...
# 60   i am new here and i do not really know how to ...
# 41   reading great expectations i noticed that numb...
# 18   i believe that to infinitive as a subject can ...
# 74   when denoting possession with bureau of statis...
# 147  there is a story that a worker at the Airport ...
# 149  there is a story that a worker at the airport ...
# 16   i believe that to infinitive as a subject can ...
# 152  there is a story that a worker at the airport ...
# 10   i say that to infinitive as a subject can be r...
# 42   reading great expectations i noticed that numb...
# 66   when denoting possession with bureau of figure...
# 141  i am not confident about my judgement as to wh...
# 160  there is a story that a worker at the airport ...
# 114  example : i had no idea how deep the forest re...
# 0    I believe that to infinitive as a subject can ...
# 106  an example just a minute ago i was looking for...
# 90   examples : jackson was a fan of the show and c...
# 7    I am not confident about my judgement as to wh...
# 40   reading great expectations i noticed that numb...
# 38   reading great expectations i noticed that numb...
# 17   i believe that to infinitive as a subject can ...
# 52   i am new here and i do not really know how to ...
# 148  there is a story that a worker at the airport ...
# 146  there is a story that a workers at the airport...
# 116  example : i had no idea how deep the forest re...
# 79   when denoting possession with bureau of statis...
# 86   examples : jackson was a fan of the show and c...
#
#                                  related_question_text     relevance  score  \
# 3     What is the correct way of these two sentence...  PerfectMatch      4
# 70    What is the correct way of these two sentence...  PerfectMatch      4
# 153  Do some google I find that clothes work like o...  PerfectMatch     12
# 50   Is this sentence grammatically correct   Anyon...  PerfectMatch     38
# 13   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 134  I came across people using all the in sentence...  PerfectMatch      5
# 115  I am not a native speaker. On a previous quest...  PerfectMatch     31
# 19   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 37   19th century English texts occasionally use Ge...  PerfectMatch     15
# 29   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 11   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 30   19th century English texts occasionally use Ge...  PerfectMatch     15
# 25   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 64    What is the correct way of these two sentence...  PerfectMatch      4
# 63   Is this sentence grammatically correct   Anyon...  PerfectMatch     38
# 111  I am not a native speaker. On a previous quest...  PerfectMatch     31
# 71    What is the correct way of these two sentence...  PerfectMatch      4
# 162  Do some google I find that clothes work like o...  PerfectMatch     12
# 43   19th century English texts occasionally use Ge...  PerfectMatch     15
# 136  I came across people using all the in sentence...  PerfectMatch      5
# 157  Do some google I find that clothes work like o...  PerfectMatch     12
# 58   Is this sentence grammatically correct   Anyon...  PerfectMatch     38
# 91   I think that "solo spot" has the same meaning,...  PerfectMatch     -2
# 159  Do some google I find that clothes work like o...  PerfectMatch     12
# 80    What is the correct way of these two sentence...  PerfectMatch      4
# 21   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 130  I came across people using all the in sentence...  PerfectMatch      5
# 143  I came across people using all the in sentence...  PerfectMatch      5
# 164  Do some google I find that clothes work like o...  PerfectMatch     12
# 99   To prevent myself from asking an obvious, sill...  PerfectMatch    102
# ..                                                 ...           ...    ...
# 109  I am not a native speaker. On a previous quest...  PerfectMatch     31
# 104  To prevent myself from asking an obvious, sill...  PerfectMatch    102
# 32   19th century English texts occasionally use Ge...  PerfectMatch     15
# 60   Is this sentence grammatically correct   Anyon...  PerfectMatch     38
# 41   19th century English texts occasionally use Ge...  PerfectMatch     15
# 18   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 74    What is the correct way of these two sentence...  PerfectMatch      4
# 147  Do some google I find that clothes work like o...  PerfectMatch     12
# 149  Do some google I find that clothes work like o...  PerfectMatch     12
# 16   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 152  Do some google I find that clothes work like o...  PerfectMatch     12
# 10   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 42   19th century English texts occasionally use Ge...  PerfectMatch     15
# 66    What is the correct way of these two sentence...  PerfectMatch      4
# 141  I came across people using all the in sentence...  PerfectMatch      5
# 160  Do some google I find that clothes work like o...  PerfectMatch     12
# 114  I am not a native speaker. On a previous quest...  PerfectMatch     31
# 0    Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 106  To prevent myself from asking an obvious, sill...  PerfectMatch    102
# 90   I think that "solo spot" has the same meaning,...  PerfectMatch     -2
# 7    I came across people using all the in sentence...  PerfectMatch      5
# 40   19th century English texts occasionally use Ge...  PerfectMatch     15
# 38   19th century English texts occasionally use Ge...  PerfectMatch     15
# 17   Is it correct to say "Would you mind to do som...  PerfectMatch     10
# 52   Is this sentence grammatically correct   Anyon...  PerfectMatch     38
# 148  Do some google I find that clothes work like o...  PerfectMatch     12
# 146  Do some google I find that clothes work like o...  PerfectMatch     12
# 116  I am not a native speaker. On a previous quest...  PerfectMatch     31
# 79    What is the correct way of these two sentence...  PerfectMatch      4
# 86   I think that "solo spot" has the same meaning,...  PerfectMatch     -2
#
#      view_count  user_id  has_accepted_answer  no_of_comments  no_of_answers  \
# 3           234  31456.0                 True               3              2
# 70          234  31456.0                 True               3              2
# 153       14184   3180.0                 True               1              4
# 50        49244     30.0                 True               1              7
# 13        52217   3027.0                 True               3              1
# 134        1822   1595.0                 True               2              3
# 115       10679   2092.0                 True               0              4
# 19        52217   3027.0                 True               3              1
# 37         1134   1638.0                 True               1              4
# 29        52217   3027.0                 True               3              1
# 11        52217   3027.0                 True               3              1
# 30         1134   1638.0                 True               1              4
# 25        52217   3027.0                 True               3              1
# 64          234  31456.0                 True               3              2
# 63        49244     30.0                 True               1              7
# 111       10679   2092.0                 True               0              4
# 71          234  31456.0                 True               3              2
# 162       14184   3180.0                 True               1              4
# 43         1134   1638.0                 True               1              4
# 136        1822   1595.0                 True               2              3
# 157       14184   3180.0                 True               1              4
# 58        49244     30.0                 True               1              7
# 91          363  37612.0                 True               1              4
# 159       14184   3180.0                 True               1              4
# 80          234  31456.0                 True               3              2
# 21        52217   3027.0                 True               3              1
# 130        1822   1595.0                 True               2              3
# 143        1822   1595.0                 True               2              3
# 164       14184   3180.0                 True               1              4
# 99         7385    519.0                 True               5             42
# ..          ...      ...                  ...             ...            ...
# 109       10679   2092.0                 True               0              4
# 104        7385    519.0                 True               5             42
# 32         1134   1638.0                 True               1              4
# 60        49244     30.0                 True               1              7
# 41         1134   1638.0                 True               1              4
# 18        52217   3027.0                 True               3              1
# 74          234  31456.0                 True               3              2
# 147       14184   3180.0                 True               1              4
# 149       14184   3180.0                 True               1              4
# 16        52217   3027.0                 True               3              1
# 152       14184   3180.0                 True               1              4
# 10        52217   3027.0                 True               3              1
# 42         1134   1638.0                 True               1              4
# 66          234  31456.0                 True               3              2
# 141        1822   1595.0                 True               2              3
# 160       14184   3180.0                 True               1              4
# 114       10679   2092.0                 True               0              4
# 0         52217   3027.0                 True               3              1
# 106        7385    519.0                 True               5             42
# 90          363  37612.0                 True               1              4
# 7          1822   1595.0                 True               2              3
# 40         1134   1638.0                 True               1              4
# 38         1134   1638.0                 True               1              4
# 17        52217   3027.0                 True               3              1
# 52        49244     30.0                 True               1              7
# 148       14184   3180.0                 True               1              4
# 146       14184   3180.0                 True               1              4
# 116       10679   2092.0                 True               0              4
# 79          234  31456.0                 True               3              2
# 86          363  37612.0                 True               1              4
#
#      total_answer_upvotes  best_answer_upvotes  jaccard_distance  \
# 3                       9                    6             0.863
# 70                      9                    6             0.863
# 153                    10                    7             0.931
# 50                     68                   44             0.859
# 13                     20                   20             0.862
# 134                     2                    2             0.864
# 115                    34                   32             0.881
# 19                     20                   20             0.862
# 37                     20                    7             0.835
# 29                     20                   20             0.862
# 11                     20                   20             0.862
# 30                     20                    7             0.835
# 25                     20                   20             0.862
# 64                      9                    6             0.863
# 63                     68                   44             0.859
# 111                    34                   32             0.881
# 71                      9                    6             0.863
# 162                    10                    7             0.931
# 43                     20                    7             0.835
# 136                     2                    2             0.864
# 157                    10                    7             0.931
# 58                     68                   44             0.859
# 91                      5                    2             0.917
# 159                    10                    7             0.931
# 80                      9                    6             0.863
# 21                     20                   20             0.862
# 130                     2                    2             0.864
# 143                     2                    2             0.864
# 164                    10                    7             0.931
# 99                    452                   31             0.909
# ..                    ...                  ...               ...
# 109                    34                   32             0.881
# 104                   452                   31             0.909
# 32                     20                    7             0.835
# 60                     68                   44             0.859
# 41                     20                    7             0.835
# 18                     20                   20             0.862
# 74                      9                    6             0.863
# 147                    10                    7             0.931
# 149                    10                    7             0.931
# 16                     20                   20             0.862
# 152                    10                    7             0.931
# 10                     20                   20             0.862
# 42                     20                    7             0.835
# 66                      9                    6             0.863
# 141                     2                    2             0.864
# 160                    10                    7             0.931
# 114                    34                   32             0.881
# 0                      20                   20             0.862
# 106                   452                   31             0.909
# 90                      5                    2             0.917
# 7                       2                    2             0.864
# 40                     20                    7             0.835
# 38                     20                    7             0.835
# 17                     20                   20             0.862
# 52                     68                   44             0.859
# 148                    10                    7             0.931
# 146                    10                    7             0.931
# 116                    34                   32             0.881
# 79                      9                    6             0.863
# 86                      5                    2             0.917
#
#      length_difference  cosine_similarity  bigram_similarity  \
# 3                   15       0.000000e+00              0.973
# 70                  15       0.000000e+00              0.973
# 153                250      -3.861439e+18              1.000
# 50                 142       0.000000e+00              1.000
# 13                  13       0.000000e+00              0.995
# 134                 12       0.000000e+00              0.979
# 115                562       0.000000e+00              0.983
# 19                  13       0.000000e+00              0.995
# 37                  24      -0.000000e+00              0.976
# 29                  13       0.000000e+00              0.995
# 11                  13       0.000000e+00              0.995
# 30                  24      -0.000000e+00              0.976
# 25                  13       0.000000e+00              0.995
# 64                  15       0.000000e+00              0.973
# 63                 142       0.000000e+00              1.000
# 111                562       0.000000e+00              0.983
# 71                  15       0.000000e+00              0.973
# 162                250      -3.861439e+18              1.000
# 43                  24      -0.000000e+00              0.976
# 136                 12       0.000000e+00              0.979
# 157                250      -3.861439e+18              1.000
# 58                 142       0.000000e+00              1.000
# 91                 122       1.750000e-01              1.000
# 159                250      -3.861439e+18              1.000
# 80                  15       0.000000e+00              0.973
# 21                  13       0.000000e+00              0.995
# 130                 12       0.000000e+00              0.979
# 143                 12       0.000000e+00              0.979
# 164                250      -3.861439e+18              1.000
# 99                  88      -1.960000e-01              1.000
# ..                 ...                ...                ...
# 109                562       0.000000e+00              0.983
# 104                 88      -1.960000e-01              1.000
# 32                  24      -0.000000e+00              0.976
# 60                 142       0.000000e+00              1.000
# 41                  24      -0.000000e+00              0.976
# 18                  13       0.000000e+00              0.995
# 74                  15       0.000000e+00              0.973
# 147                250      -3.861439e+18              1.000
# 149                250      -3.861439e+18              1.000
# 16                  13       0.000000e+00              0.995
# 152                250      -3.861439e+18              1.000
# 10                  13       0.000000e+00              0.995
# 42                  24      -0.000000e+00              0.976
# 66                  15       0.000000e+00              0.973
# 141                 12       0.000000e+00              0.979
# 160                250      -3.861439e+18              1.000
# 114                562       0.000000e+00              0.983
# 0                   13       0.000000e+00              0.995
# 106                 88      -1.960000e-01              1.000
# 90                 122       1.750000e-01              1.000
# 7                   12       0.000000e+00              0.979
# 40                  24      -0.000000e+00              0.976
# 38                  24      -0.000000e+00              0.976
# 17                  13       0.000000e+00              0.995
# 52                 142       0.000000e+00              1.000
# 148                250      -3.861439e+18              1.000
# 146                250      -3.861439e+18              1.000
# 116                562       0.000000e+00              0.983
# 79                  15       0.000000e+00              0.973
# 86                 122       1.750000e-01              1.000
#
#      w2v_cosine_similarity
# 3                    0.534
# 70                   0.534
# 153                  0.843
# 50                   0.816
# 13                   0.917
# 134                  0.880
# 115                  0.917
# 19                   0.917
# 37                   0.895
# 29                   0.917
# 11                   0.917
# 30                   0.895
# 25                   0.917
# 64                   0.534
# 63                   0.816
# 111                  0.917
# 71                   0.534
# 162                  0.843
# 43                   0.895
# 136                  0.880
# 157                  0.843
# 58                   0.816
# 91                   0.736
# 159                  0.843
# 80                   0.534
# 21                   0.917
# 130                  0.880
# 143                  0.880
# 164                  0.843
# 99                   0.787
# ..                     ...
# 109                  0.917
# 104                  0.787
# 32                   0.895
# 60                   0.816
# 41                   0.895
# 18                   0.917
# 74                   0.534
# 147                  0.843
# 149                  0.843
# 16                   0.917
# 152                  0.843
# 10                   0.917
# 42                   0.895
# 66                   0.534
# 141                  0.880
# 160                  0.843
# 114                  0.917
# 0                    0.917
# 106                  0.787
# 90                   0.736
# 7                    0.880
# 40                   0.895
# 38                   0.895
# 17                   0.917
# 52                   0.816
# 148                  0.843
# 146                  0.843
# 116                  0.917
# 79                   0.534
# 86                   0.736
#
# [168 rows x 18 columns]
