# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
training_df = pd.read_csv('/Volumes/DataDrive/training/logs/logs/train-1.csv')

# %%
training_df.head(n=5)
# Out:
#    epoch       acc  f2_score      loss  mean_absolute_error   val_acc  \
# 0      0  0.799532  0.000941  0.174963             0.233071  0.801667
# 1      1  0.810828  0.012351  0.149244             0.237767  0.818333
# 2      2  0.829597  0.031320  0.129337             0.236483  0.834333
# 3      3  0.844115  0.045895  0.116389             0.231800  0.844667
# 4      4  0.860945  0.062696  0.106720             0.225293  0.868667
#
#    val_f2_score  val_loss  val_mean_absolute_error
# 0      0.001333  0.163066                 0.237894
# 1      0.018000  0.140858                 0.241661
# 2      0.034000  0.125531                 0.239418
# 3      0.044333  0.114486                 0.233929
# 4      0.068333  0.104656                 0.226755

# %%
acc = training_df['acc'].values
val_acc = training_df['val_acc'].values
loss = training_df['loss'].values
val_loss = training_df['val_loss'].values

# Plot accuracy
plt.plot(acc)
plt.plot(val_acc)
plt.title('Dokładność modelu')
plt.ylabel('Dokładność')
plt.xlabel('Epoka')
plt.legend(['Trening', 'Walidacja'], loc='upper left')
plt.show()

# Plot loss
plt.plot(loss)
plt.plot(val_loss)
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoka')
plt.legend(['Trening', 'Walidacja'], loc='upper right')
plt.show()

# %%
f2_score = training_df['f2_score'].values

# Plot F2 Score
plt.plot(f2_score)
plt.title('Wartość F2')
plt.ylabel('Wartość')
plt.xlabel('Epoka')
plt.legend(['Trening'], loc='upper left')
plt.show()
